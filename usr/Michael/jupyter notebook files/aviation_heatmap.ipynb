# %%
import gmaps
import pandas as pd

# Google developer API key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
# Create aiport dataframe
aviation_df = pd.read_csv('data/damage_rating.csv')
# aviation_df.dropna()
aviation_df.head()
# Out:
#    Unnamed: 0        Event_Id  Event_Date       Location        Country  \
# 0           0  20200102X82407  12/31/2019        Elk, CA  United States
# 1           1  20191231X83852  12/31/2019     OLATHE, KS  United States
# 2           2  20200102X54844  12/31/2019  Fairbanks, AK  United States
# 3           3  20191230X91852  12/30/2019   GRANBURY, TX  United States
# 4           4  20191228X23853  12/28/2019  LAFAYETTE, LA  United States
#
#     Latitude   Longitude Airport_Code Injury_Severity Aircraft_Damage  \
# 0  39.128611 -123.715833          LLR       Non-Fatal     Substantial
# 1  38.846111  -94.736111          OJC        Fatal(2)       Destroyed
# 2  64.666945 -148.133334      UNKNOWN       Non-Fatal     Substantial
# 3  32.365556  -97.645000      UNKNOWN       Non-Fatal     Substantial
# 4  30.176111  -92.007500          LFT        Fatal(5)       Destroyed
#
#   Aircraft_Category    Make   Model  Total_Fatal_Injuries  \
# 0          Airplane  Cessna     175                     0
# 1          Airplane  Mooney    M20S                     2
# 2          Airplane  Cessna     170                     0
# 3          Airplane    Vans   RV 10                     0
# 4          Airplane   Piper  PA 31T                     5
#
#    Total_Serious_Injuries  Total_Minor_Injuries  Total_Uninjured  \
# 0                       0                     0                1
# 1                       0                     0                0
# 2                       0                     0                2
# 3                       0                     0                1
# 4                       2                     2                0
#
#   Broad_Phase_of_Flight  Damage_Rating
# 0               TAKEOFF            2.0
# 1               TAKEOFF            3.0
# 2               UNKNOWN            2.0
# 3               UNKNOWN            2.0
# 4               TAKEOFF            3.0

# %%
aviation_df.shape
# Out:
# (29388, 19)

# %%
# Store latitude and longitude in locations
locations = aviation_df[["Latitude", "Longitude"]]

# Fill NaN values and convert to float
rating = aviation_df["Damage_Rating"].astype(float)

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=100,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
