# %%
import pandas as pd

# %%
df = pd.read_csv('AviationData.csv', encoding = "ISO-8859-1")

# %%
df.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20200102X82407           Accident      WPR20CA055  2019-12-31
# 1  20191231X83852           Accident      CEN20FA049  2019-12-31
# 2  20200102X54844           Accident      ANC20CA011  2019-12-31
# 3  20191230X91852           Accident      CEN20CA048  2019-12-30
# 4  20191228X62945                NaN      WPR20CA053  2019-12-28
#
#         Location        Country   Latitude   Longitude Airport.Code  \
# 0        Elk, CA  United States  39.128611 -123.715833          LLR
# 1     OLATHE, KS  United States  38.846111  -94.736111          OJC
# 2  Fairbanks, AK  United States  64.666945 -148.133334          NaN
# 3   GRANBURY, TX  United States  32.365556  -97.645000          NaN
# 4   Missoula, MT  United States        NaN         NaN          MSO
#
#                Airport.Name  ... Purpose.of.Flight Air.Carrier  \
# 0              Little River  ...          Personal         NaN
# ...

# %%
cols_to_drop = ['Investigation.Type','Accident.Number','Airport.Name','Registration.Number','Amateur.Built',\
               'Number.of.Engines', 'Engine.Type', 'FAR.Description', 'Schedule', 'Purpose.of.Flight',\
               'Air.Carrier', 'Weather.Condition','Report.Status','Publication.Date']

# %%
df.drop(cols_to_drop, 1, inplace=True)

# %%
df.head()
# Out:
#          Event.Id  Event.Date       Location        Country   Latitude  \
# 0  20200102X82407  2019-12-31        Elk, CA  United States  39.128611
# 1  20191231X83852  2019-12-31     OLATHE, KS  United States  38.846111
# 2  20200102X54844  2019-12-31  Fairbanks, AK  United States  64.666945
# 3  20191230X91852  2019-12-30   GRANBURY, TX  United States  32.365556
# 4  20191228X62945  2019-12-28   Missoula, MT  United States        NaN
#
#     Longitude Airport.Code Injury.Severity Aircraft.Damage Aircraft.Category  \
# 0 -123.715833          LLR       Non-Fatal     Substantial          Airplane
# 1  -94.736111          OJC        Fatal(2)       Destroyed          Airplane
# 2 -148.133334          NaN       Non-Fatal     Substantial          Airplane
# 3  -97.645000          NaN       Non-Fatal     Substantial          Airplane
# 4         NaN          MSO     Unavailable     Substantial               NaN
#
#      Make  Model  Total.Fatal.Injuries  Total.Serious.Injuries  \
# ...

# %%
# fill NaN in injury columns with zeroes as they should be. 

df['Total.Fatal.Injuries'].fillna(0, inplace=True)

# %%
df['Total.Serious.Injuries'].fillna(0, inplace=True)
df['Total.Minor.Injuries'].fillna(0, inplace=True)
df['Total.Uninjured'].fillna(0, inplace=True)

# %%
df.head()
# Out:
#          Event.Id  Event.Date       Location        Country   Latitude  \
# 0  20200102X82407  2019-12-31        Elk, CA  United States  39.128611
# 1  20191231X83852  2019-12-31     OLATHE, KS  United States  38.846111
# 2  20200102X54844  2019-12-31  Fairbanks, AK  United States  64.666945
# 3  20191230X91852  2019-12-30   GRANBURY, TX  United States  32.365556
# 4  20191228X62945  2019-12-28   Missoula, MT  United States        NaN
#
#     Longitude Airport.Code Injury.Severity Aircraft.Damage Aircraft.Category  \
# 0 -123.715833          LLR       Non-Fatal     Substantial          Airplane
# 1  -94.736111          OJC        Fatal(2)       Destroyed          Airplane
# 2 -148.133334          NaN       Non-Fatal     Substantial          Airplane
# 3  -97.645000          NaN       Non-Fatal     Substantial          Airplane
# 4         NaN          MSO     Unavailable     Substantial               NaN
#
#      Make  Model  Total.Fatal.Injuries  Total.Serious.Injuries  \
# ...

# %%
# fill NaN in flight phase with UNKNOWNs. 

df['Broad.Phase.of.Flight'].fillna('UNKNOWN', inplace=True)

# %%
df.head()
# Out:
#          Event.Id  Event.Date       Location        Country   Latitude  \
# 0  20200102X82407  2019-12-31        Elk, CA  United States  39.128611
# 1  20191231X83852  2019-12-31     OLATHE, KS  United States  38.846111
# 2  20200102X54844  2019-12-31  Fairbanks, AK  United States  64.666945
# 3  20191230X91852  2019-12-30   GRANBURY, TX  United States  32.365556
# 4  20191228X62945  2019-12-28   Missoula, MT  United States        NaN
#
#     Longitude Airport.Code Injury.Severity Aircraft.Damage Aircraft.Category  \
# 0 -123.715833          LLR       Non-Fatal     Substantial          Airplane
# 1  -94.736111          OJC        Fatal(2)       Destroyed          Airplane
# 2 -148.133334          NaN       Non-Fatal     Substantial          Airplane
# 3  -97.645000          NaN       Non-Fatal     Substantial          Airplane
# 4         NaN          MSO     Unavailable     Substantial               NaN
#
#      Make  Model  Total.Fatal.Injuries  Total.Serious.Injuries  \
# ...

# %%
# drop accidents with no coordinates

df.dropna(subset=['Latitude'], inplace=True)

# %%
df.head()
# Out:
#          Event.Id  Event.Date       Location        Country   Latitude  \
# 0  20200102X82407  2019-12-31        Elk, CA  United States  39.128611
# 1  20191231X83852  2019-12-31     OLATHE, KS  United States  38.846111
# 2  20200102X54844  2019-12-31  Fairbanks, AK  United States  64.666945
# 3  20191230X91852  2019-12-30   GRANBURY, TX  United States  32.365556
# 5  20191228X23853  2019-12-28  LAFAYETTE, LA  United States  30.176111
#
#     Longitude Airport.Code Injury.Severity Aircraft.Damage Aircraft.Category  \
# 0 -123.715833          LLR       Non-Fatal     Substantial          Airplane
# 1  -94.736111          OJC        Fatal(2)       Destroyed          Airplane
# 2 -148.133334          NaN       Non-Fatal     Substantial          Airplane
# 3  -97.645000          NaN       Non-Fatal     Substantial          Airplane
# 5  -92.007500          LFT        Fatal(5)       Destroyed          Airplane
#
#      Make   Model  Total.Fatal.Injuries  Total.Serious.Injuries  \
# ...

# %%
# fill NaN Airport codes

df['Airport.Code'].fillna('UNKNOWN', inplace=True)

# %%
# fill NaN Aircraft categories

df['Aircraft.Category'].fillna('Unknown', inplace=True)

# %%
df['Make'].fillna('Unknown', inplace=True)
df['Model'].fillna('Unknown', inplace=True)

# %%
df['Location'].fillna('Unknown', inplace=True)
df['Country'].fillna('Unknown', inplace=True)
df['Injury.Severity'].fillna('Unknown', inplace=True)
df['Aircraft.Damage'].fillna('Unknown', inplace=True)

# %%
df.sample(10)
# Out:
#              Event.Id  Event.Date             Location        Country  \
# 26712  20040929X01515  2004-09-23           Milton, FL  United States
# 3396   20171007X12946  2017-10-07          Topping, VA  United States
# 1261   20190315X83105  2019-03-15           Madras, OR  United States
# 28662  20031001X01642  2003-09-28     Roche Harbor, WA  United States
# 15030  20101102X13215  2010-10-25           Lander, WY  United States
# 27776  20040413X00454  2004-04-11           Denver, CO  United States
# 25902  20050419X00477  2005-03-25  West Palm Beach, FL  United States
# 7829   20150205X34400  2015-02-05          Andrews, TX  United States
# 24291  20060111X00049  2005-12-16           Stuart, FL  United States
# 3918   20170707X85152  2017-07-07       Pine Bluff, AR  United States
#
#         Latitude   Longitude Airport.Code Injury.Severity Aircraft.Damage  \
# 26712  30.645277  -86.998611          2R4        Fatal(4)       Destroyed
# ...

# %%
df.to_csv('cleaned_data.csv')
